# %%
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
import io
import re

# ✅ Extract text from PDF using PyMuPDF
def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        doc = fitz.open(pdf_path)
        for page in doc:
            text += page.get_text("text")

        if not text.strip():
            print(f"⚠️ No text found in {pdf_path}! Trying OCR on images...")
            for page_num in range(len(doc)):
                img = page_to_image(doc, page_num)
                extracted_text = pytesseract.image_to_string(img)
                text += extracted_text

        return text.strip() if text else "OCR Failed"
    except Exception as e:
        print(f"❌ Error extracting text: {e}")
        return "OCR Failed"

# ✅ Convert PDF page to image for OCR
def page_to_image(doc, page_num):
    page = doc[page_num]
    pix = page.get_pixmap()
    img = Image.open(io.BytesIO(pix.tobytes("ppm")))
    return img

# ✅ Extract only required IELTS fields
def extract_ielts_details(text):
    extracted_data = {}

    # **Extract Candidate ID**
    candidate_id_match = re.search(r'Candidate ID[:\s]*([A-Za-z0-9]+)', text, re.IGNORECASE)
    if candidate_id_match:
        extracted_data["candidate_id"] = candidate_id_match.group(1)

    # **Extract Date of Birth**
    dob_match = re.search(r'Date of Birth[:\s]*(\d{2}/\d{2}/\d{4})', text)
    if dob_match:
        extracted_data["dob"] = dob_match.group(1)

    # **Extract Center Number**
    center_number_match = re.search(r'Centre Number[:\s]*([A-Za-z0-9]+)', text, re.IGNORECASE)
    if center_number_match:
        extracted_data["center_number"] = center_number_match.group(1)

    # **Extract Test Date**
    test_date_match = re.search(r'Test Date[:\s]*(\d{2}/\d{2}/\d{4})', text)
    if test_date_match:
        extracted_data["test_date"] = test_date_match.group(1)

    # **Extract Scores**
    score_fields = {
        "listening": r'Listening[:\s]+(\d+\.\d+)',
        "reading": r'Reading[:\s]+(\d+\.\d+)',
        "writing": r'Writing[:\s]+(\d+\.\d+)',
        "speaking": r'Speaking[:\s]+(\d+\.\d+)',
    }

    for key, pattern in score_fields.items():
        match = re.search(pattern, text)
        if match:
            extracted_data[key] = match.group(1)  # Keep as string

    return extracted_data  # ✅ Return only extracted fields

# ✅ File Path for IELTS PDF
ielts_pdf_path = "IELTS.pdf"

# ✅ Extract Text from IELTS PDF
ielts_text = extract_text_from_pdf(ielts_pdf_path)

# ✅ Extract IELTS Details
ielts_details = extract_ielts_details(ielts_text)

# ✅ Print Only Extracted Fields
print("\n📄 **Extracted IELTS Details:**")
print(ielts_details)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import fitz  # PyMuPDF
#       2 import pytesseract
#       3 from PIL import Image
#
# File ~\anaconda3\Lib\site-packages\fitz\__init__.py:1
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#
# ModuleNotFoundError: No module named 'frontend'

# %%
pip install fitz
# Out:
# Collecting fitz
#   Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl.metadata (816 bytes)
# Requirement already satisfied: configobj in c:\users\niharika\anaconda3\lib\site-packages (from fitz) (5.0.9)
# Collecting configparser (from fitz)
#   Downloading configparser-7.2.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting httplib2 (from fitz)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting nibabel (from fitz)
#   Downloading nibabel-5.3.2-py3-none-any.whl.metadata (9.1 kB)
# Collecting nipype (from fitz)
#   Downloading nipype-1.10.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numpy in c:\users\niharika\appdata\roaming\python\python311\site-packages (from fitz) (1.24.3)
# Requirement already satisfied: pandas in c:\users\niharika\appdata\roaming\python\python311\site-packages (from fitz) (2.0.2)
# Collecting pyxnat (from fitz)
#   Downloading pyxnat-1.6.3-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scipy in c:\users\niharika\appdata\roaming\python\python311\site-packages (from fitz) (1.10.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from httplib2->fitz) (3.1.1)
# Collecting importlib-resources>=5.12 (from nibabel->fitz)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: packaging>=20 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from nibabel->fitz) (23.2)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from nibabel->fitz) (4.12.2)
# Requirement already satisfied: click>=6.6.0 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from nipype->fitz) (8.1.7)
# Requirement already satisfied: networkx>=2.5 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from nipype->fitz) (3.3)
# Collecting prov>=1.5.2 (from nipype->fitz)
#   Downloading prov-2.0.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pydot>=1.2.3 in c:\users\niharika\anaconda3\lib\site-packages (from nipype->fitz) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from nipype->fitz) (2.8.2)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting simplejson>=3.8.0 (from nipype->fitz)
#   Downloading simplejson-3.20.1-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Collecting traits>=6.2 (from nipype->fitz)
#   Downloading traits-7.0.2-cp311-cp311-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: filelock>=3.0.0 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from nipype->fitz) (3.15.4)
# Collecting acres (from nipype->fitz)
#   Downloading acres-0.3.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting etelemetry>=0.3.1 (from nipype->fitz)
#   Downloading etelemetry-0.3.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting looseversion!=1.2 (from nipype->fitz)
#   Downloading looseversion-1.3.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting puremagic (from nipype->fitz)
#   Downloading puremagic-1.28-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from pandas->fitz) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\niharika\anaconda3\lib\site-packages (from pandas->fitz) (2023.3)
# Requirement already satisfied: lxml>=4.3 in c:\users\niharika\anaconda3\lib\site-packages (from pyxnat->fitz) (4.9.3)
# Requirement already satisfied: requests>=2.20 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from pyxnat->fitz) (2.32.3)
# Requirement already satisfied: pathlib>=1.0 in c:\users\niharika\anaconda3\lib\site-packages (from pyxnat->fitz) (1.0.1)
# Requirement already satisfied: colorama in c:\users\niharika\appdata\roaming\python\python311\site-packages (from click>=6.6.0->nipype->fitz) (0.4.6)
# Collecting ci-info>=0.2 (from etelemetry>=0.3.1->nipype->fitz)
#   Downloading ci_info-0.3.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-6.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: six>=1.5 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.2->nipype->fitz) (1.16.0)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=5.0.0->nipype->fitz)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from requests>=2.20->pyxnat->fitz) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from requests>=2.20->pyxnat->fitz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\niharika\anaconda3\lib\site-packages (from requests>=2.20->pyxnat->fitz) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\niharika\appdata\roaming\python\python311\site-packages (from requests>=2.20->pyxnat->fitz) (2024.2.2)
# Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl (20 kB)
# Downloading configparser-7.2.0-py3-none-any.whl (17 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#    ---------------------------------------- 96.9/96.9 kB 5.8 MB/s eta 0:00:00
# Downloading nibabel-5.3.2-py3-none-any.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/3.3 MB 14.1 MB/s eta 0:00:01
#    -------- ------------------------------- 0.7/3.3 MB 11.4 MB/s eta 0:00:01
#    --------------- ------------------------ 1.3/3.3 MB 11.6 MB/s eta 0:00:01
#    ------------------- -------------------- 1.6/3.3 MB 11.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.0/3.3 MB 9.6 MB/s eta 0:00:01
#    --------------------------- ------------ 2.3/3.3 MB 9.7 MB/s eta 0:00:01
#    ------------------------------- -------- 2.6/3.3 MB 8.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.9/3.3 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 8.4 MB/s eta 0:00:00
# Downloading nipype-1.10.0-py3-none-any.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ----- ---------------------------------- 0.4/3.2 MB 9.2 MB/s eta 0:00:01
#    -------- ------------------------------- 0.7/3.2 MB 8.6 MB/s eta 0:00:01
#    ------------ --------------------------- 1.0/3.2 MB 7.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.3/3.2 MB 7.7 MB/s eta 0:00:01
#    -------------------- ------------------- 1.6/3.2 MB 6.9 MB/s eta 0:00:01
#    ------------------------ --------------- 1.9/3.2 MB 6.9 MB/s eta 0:00:01
#    ------------------------- -------------- 2.1/3.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.3/3.2 MB 6.4 MB/s eta 0:00:01
#    -------------------------------- ------- 2.6/3.2 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 7.0 MB/s eta 0:00:00
# Downloading pyxnat-1.6.3-py3-none-any.whl (95 kB)
#    ---------------------------------------- 0.0/95.4 kB ? eta -:--:--
#    ---------------------------------------- 95.4/95.4 kB 5.3 MB/s eta 0:00:00
# Downloading etelemetry-0.3.1-py3-none-any.whl (6.4 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Downloading prov-2.0.1-py3-none-any.whl (421 kB)
#    ---------------------------------------- 0.0/421.5 kB ? eta -:--:--
#    ---------------------------------------  419.8/421.5 kB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 421.5/421.5 kB 8.8 MB/s eta 0:00:00
# Downloading rdflib-6.3.2-py3-none-any.whl (528 kB)
#    ---------------------------------------- 0.0/528.1 kB ? eta -:--:--
#    ------------------------ --------------- 327.7/528.1 kB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 528.1/528.1 kB 8.2 MB/s eta 0:00:00
# Downloading simplejson-3.20.1-cp311-cp311-win_amd64.whl (75 kB)
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB ? eta 0:00:00
# Downloading traits-7.0.2-cp311-cp311-win_amd64.whl (5.0 MB)
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/5.0 MB 16.8 MB/s eta 0:00:01
#    ------- -------------------------------- 1.0/5.0 MB 12.1 MB/s eta 0:00:01
#    --------- ------------------------------ 1.2/5.0 MB 8.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.5/5.0 MB 8.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.2/5.0 MB 9.3 MB/s eta 0:00:01
#    --------------------- ------------------ 2.7/5.0 MB 10.0 MB/s eta 0:00:01
#    ------------------------ --------------- 3.1/5.0 MB 9.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.6/5.0 MB 10.1 MB/s eta 0:00:01
#    ------------------------------- -------- 4.0/5.0 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 4.7/5.0 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------- 5.0/5.0 MB 10.1 MB/s eta 0:00:00
# Downloading acres-0.3.0-py3-none-any.whl (10 kB)
# Downloading puremagic-1.28-py3-none-any.whl (43 kB)
#    ---------------------------------------- 0.0/43.2 kB ? eta -:--:--
#    ---------------------------------------- 43.2/43.2 kB ? eta 0:00:00
# Downloading ci_info-0.3.0-py3-none-any.whl (7.8 kB)
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#    ---------------------------------------- 41.7/41.7 kB ? eta 0:00:00
# Installing collected packages: puremagic, looseversion, traits, simplejson, isodate, importlib-resources, httplib2, configparser, ci-info, acres, rdflib, pyxnat, nibabel, etelemetry, prov, nipype, fitz
# Successfully installed acres-0.3.0 ci-info-0.3.0 configparser-7.2.0 etelemetry-0.3.1 fitz-0.0.1.dev2 httplib2-0.22.0 importlib-resources-6.5.2 isodate-0.6.1 looseversion-1.3.0 nibabel-5.3.2 nipype-1.10.0 prov-2.0.1 puremagic-1.28 pyxnat-1.6.3 rdflib-6.3.2 simplejson-3.20.1 traits-7.0.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 25.0.1
# [notice] To update, run: C:\Users\NIHARIKA\anaconda3\python.exe -m pip install --upgrade pip
